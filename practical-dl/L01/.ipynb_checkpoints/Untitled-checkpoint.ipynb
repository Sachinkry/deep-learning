# %%
pip install -Uqq fastai duckduckgo_search
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'C:\\Python310\\Scripts\\ddgs.exe' -> 'C:\\Python310\\Scripts\\ddgs.exe.deleteme'

# %%
from duckduckgo_search import DDGS
from fastcore.all import *

def search_images(term, max_images=30):
    print(f"searching for '{term}'")
    return L(DDGS().images(term, max_results=max_images)).itemgot('image')

urls = search_images('bird photos', max_images=1)
urls[0]
# Out:
# searching for 'bird photos'
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[2], line 8
#       5     print(f"searching for '{term}'")
#       6     return L(DDGS().images(term, max_results=max_images)).itemgot('image')
# ----> 8 urls = search_images('bird photos', max_images=1)
#       9 urls[0]
#
# Cell In[2], line 6, in search_images(term, max_images)
#       4 def search_images(term, max_images=30):
#       5     print(f"searching for '{term}'")
# ----> 6     return L(DDGS().images(term, max_results=max_images)).itemgot('image')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\fastcore\foundation.py:98, in _L_Meta.__call__(cls, x, *args, **kwargs)
#      96 def __call__(cls, x=None, *args, **kwargs):
#      97     if not args and not kwargs and x is not None and isinstance(x,cls): return x
# ---> 98     return super().__call__(x, *args, **kwargs)
#
# ...

# %%
urls = search_images('bird photos', max_images=1)
urls[0]
# Out:
# searching for 'bird photos'
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 urls = search_images('bird photos', max_images=1)
#       2 urls[0]
#
# Cell In[4], line 6, in search_images(term, max_images)
#       4 def search_images(term, max_images=30):
#       5     print(f"searching for '{term}'")
# ----> 6     return L(DDGS().images(term, max_results=max_images)).itemgot('image')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\fastcore\foundation.py:98, in _L_Meta.__call__(cls, x, *args, **kwargs)
#      96 def __call__(cls, x=None, *args, **kwargs):
#      97     if not args and not kwargs and x is not None and isinstance(x,cls): return x
# ---> 98     return super().__call__(x, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\fastcore\foundation.py:106, in L.__init__(self, items, use_list, match, *rest)
# ...

# %%
from fastdownload import download_url
dest = 'bird.jpg'
download_url(urls[0], dest, show_progress=False)
# Out:
# Path('bird.jpg')

# %%
from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256, 256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x160>

# %%
# let's bring and show a forest photo
download_url(search_images('forest photos', max_images=1)[0], 'forest.jpg', show_progress=False)
Image.open('forest.jpg').to_thumb(256, 256)
# Out:
# searching for 'forest photos'
# <PIL.Image.Image image mode=RGB size=256x144>

# %%
for o in searches:
    dest = path/o   # e.g., bird_or_not/forest
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f'{o} photo'))

    # Attempt to resize images using parallel processing
    try:
        resize_images(path/o, max_size=400, dest=path/o)
    except Exception as e:
        print(f"Parallel processing failed for {o}: {e}")
        print("Resizing images sequentially as a fallback.")

        # Sequentially resize images if parallel processing fails
        for img_path in get_image_files(dest):
            try:
                img = Image.open(img_path)
                img = img.resize((400, 400))  # Resize the image
                img.save(img_path)  # Save the resized image
            except Exception as e:
                print(f"Failed to process image {img_path}: {e}")
# Out:
# searching for 'forest photo'
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[7], line 8
#       6 dest.mkdir(exist_ok=True, parents=True)
#       7 download_images(dest, urls=search_images(f'{o} photo'))
# ----> 8 resize_images(path/o, max_size=400, dest=path/o)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\fastai\vision\utils.py:102, in resize_images(path, max_workers, max_size, recurse, dest, n_channels, ext, img_format, resample, resume, **kwargs)
#     100 files = get_image_files(path, recurse=recurse)
#     101 files = [o.relative_to(path) for o in files]
# --> 102 parallel(resize_image, files, src=path, n_workers=max_workers, max_size=max_size, dest=dest, n_channels=n_channels, ext=ext,
#     103                img_format=img_format, resample=resample, resume=resume, **kwargs)
#
# ...

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 failed = verify_images(get_image_files(path))
#       2 failed.map(Path.unlink)
#       3 len(failed)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\fastai\vision\utils.py:66, in verify_images(fns)
#      64 def verify_images(fns):
#      65     "Find images in `fns` that can't be opened"
# ---> 66     return L(fns[i] for i,o in enumerate(parallel(verify_image, fns)) if not o)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\fastcore\parallel.py:117, in parallel(f, items, n_workers, total, progress, pause, method, threadpool, timeout, chunksize, *args, **kwargs)
#     115     if total is None: total = len(items)
#     116     r = progress_bar(r, total=total, leave=False)
# --> 117 return L(r)
#
# ...

# %%
# classify the sentiment of movie review better
from fastai.text.all import *

dls = TextDataLoaders.from_folder(untar_data(URLs.IMDB), valid='test')
learn = text_classifier_learner(
    dls, 
    AWD_LSTM, 
    drop_mult=0.5, 
    metrics=accuracy
)

learn.fine_tune(4, 1e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='144441344' class='' max='144440600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [144441344/144440600 00:25&lt;00:00]
#     </div>
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `n_workers` has to be changed to 0 to avoid getting stuck
# ...

# %%
1+1
